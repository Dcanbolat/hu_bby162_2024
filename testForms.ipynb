# %% [markdown]
# <a href="https://colab.research.google.com/github/Dcanbolat/hu_bby162_2024/blob/main/testForms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# Web sayfasını çek
url = "https://hacettepe.edu.tr"   # istediğiniz web sayfasının URL'sini girin
response = requests.get(url)
htmlIcerigi = response.content

# BeautifulSoup nesnesi oluştur
soup = BeautifulSoup(htmlIcerigi, "html.parser")

# Başlığı bul ve yazdır
baslik = soup.find("title").text
print("Başlık:", baslik)

# Sayfadaki tüm bağlantıları al
linkler = soup.find_all('a')
for link in linkler:
    print("Bağlantı", link.get('href'))
# Out:
# Başlık: Hacettepe Üniversitesi
# Bağlantı /
# Bağlantı https://huysis.hacettepe.edu.tr
# Bağlantı /hakkinda/arama
# Bağlantı https://bidb.hacettepe.edu.tr/tr/e-posta
# Bağlantı https://www.instagram.com/hacettepe_university/
# Bağlantı https://www.facebook.com/HacettepeUniversitesiKurumsal
# Bağlantı https://twitter.com/Hacettepe1967
# Bağlantı https://www.youtube.com/HacettepeKurumsal/
# Bağlantı /kalite
# Bağlantı /ogrenci
# Bağlantı /personel
# Bağlantı https://mezunum.hacettepe.edu.tr/
# Bağlantı https://universitem.hacettepe.edu.tr/
# Bağlantı /hakkinda/iletisim
# Bağlantı https://kalite.hacettepe.edu.tr/tr/geribildirim
# Bağlantı /english
# Bağlantı /ogretim
# Bağlantı /arastirma
# Bağlantı /inovasyon
# Bağlantı /toplumsalkatki
# Bağlantı /saglik
# Bağlantı /uluslararasi
# Bağlantı /yerleskedeyasam
# Bağlantı /hakkinda
# Bağlantı /kalite
# Bağlantı /ogrenci
# Bağlantı /personel
# Bağlantı https://mezunum.hacettepe.edu.tr/
# Bağlantı https://universitem.hacettepe.edu.tr/
# ...
